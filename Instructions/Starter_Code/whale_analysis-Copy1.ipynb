# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
Whalecsv = Path("../Starter_Code/Resources/whale_returns.csv")

# %%
Whalecsv
# Out:
# WindowsPath('../Starter_Code/Resources/whale_returns.csv')

# %%
whalesr_df = pd.read_csv(Whalecsv, index_col="Date", parse_dates = True, infer_datetime_format =True) 
whalesr_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whalesr_df.isnull().count()
# Out:
# SOROS FUND MANAGEMENT LLC      1060
# PAULSON & CO.INC.              1060
# TIGER GLOBAL MANAGEMENT LLC    1060
# BERKSHIRE HATHAWAY INC         1060
# dtype: int64

# %%
# Drop nulls
whalesr_df.dropna(inplace=True)
whalesr_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
whalesr_df = whalesr_df.rename(columns={"Date": "Date", "SOROS FUND MANAGEMENT LLC": "Soros", "PAULSON & CO.INC. ": "Paulson", "TIGER GLOBAL MANAGEMENT LLC": "Tiger Global", "BERKSHIRE HATHAWAY INC": "BRK"})
whalesr_df.head()
# Out:
#                Soros   Paulson  Tiger Global       BRK
# Date
# 2015-03-03 -0.001266 -0.004981     -0.000496 -0.006569
# 2015-03-04  0.002230  0.003241     -0.002534  0.004213
# 2015-03-05  0.004016  0.004076      0.002355  0.006726
# 2015-03-06 -0.007905 -0.003574     -0.008481 -0.013098
# 2015-03-09  0.000582  0.004225      0.005843 -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
Algocsv = Path("../Starter_Code/Resources/algo_returns.csv")

# %%
Algocsv
# Out:
# WindowsPath('../Starter_Code/Resources/algo_returns.csv')

# %%
algod_df = pd.read_csv(Algocsv, index_col="Date", parse_dates = True, infer_datetime_format =True) 
algod_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algod_df.isnull().count()
# Out:
# Algo 1    1241
# Algo 2    1241
# dtype: int64

# %%
# Drop nulls
algod_df.dropna(inplace=True)
algod_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
Sp500csv = Path("../Starter_Code/Resources/sp500_history.csv")

# %%
Sp500csv
# Out:
# WindowsPath('../Starter_Code/Resources/sp500_history.csv')

# %%
Sp500h_df = pd.read_csv(Sp500csv, index_col="Date", parse_dates = True, infer_datetime_format =True) 
Sp500h_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
Sp500h_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# This code allows me to drop the $ sign from the number
Sp500h_df['Close'] = Sp500h_df['Close'].str.replace('$','')

# %%
Sp500h_df.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
Sp500h_df["Close"] = Sp500h_df["Close"].astype(float)

# %%
Sp500h_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
Sp500h_df.set_index('Close')
daily_returns = Sp500h_df['Close'].pct_change()
daily_returns.head()
# Out:
# Date
# 2019-04-23         NaN
# 2019-04-22   -0.008764
# 2019-04-18   -0.001011
# 2019-04-17   -0.001577
# 2019-04-16    0.002279
# Name: Close, dtype: float64

# %%
# Drop nulls
daily_returns.dropna(inplace=True)
daily_returns
# Out:
# Date
# 2019-04-22   -0.008764
# 2019-04-18   -0.001011
# 2019-04-17   -0.001577
# 2019-04-16    0.002279
# 2019-04-15   -0.000509
#                 ...
# 2012-10-05    0.003469
# 2012-10-04    0.000322
# 2012-10-03   -0.007123
# 2012-10-02   -0.003611
# 2012-10-01   -0.000872
# Name: Close, Length: 1648, dtype: float64

# %%
# Rename `Close` Column to be specific to this portfolio.
Sp500h_df = Sp500h_df.rename(columns={"Date": "Date", "Close": "SP Close"})
Sp500h_df.head()
# Out:
#             SP Close
# Date
# 2019-04-23   2933.68
# 2019-04-22   2907.97
# 2019-04-18   2905.03
# 2019-04-17   2900.45
# 2019-04-16   2907.06

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_WASP_df = pd.concat([whalesr_df, algod_df, daily_returns, Sp500h_df], axis="columns", join="inner")
combined_WASP_df.sort_index(inplace=True)
combined_WASP_df.columns = ['Soros', 'Paulson', 'Tiger Global', 'BRK', 'Algo 1', 'Algo 2', 'SP Daily Returns', 'SP Close']
combined_WASP_df.head()
# Out:
#                Soros   Paulson  Tiger Global       BRK    Algo 1    Algo 2  \
# Date
# 2015-03-03 -0.001266 -0.004981     -0.000496 -0.006569 -0.001942 -0.000949
# 2015-03-04  0.002230  0.003241     -0.002534  0.004213 -0.008589  0.002416
# 2015-03-05  0.004016  0.004076      0.002355  0.006726 -0.000955  0.004323
# 2015-03-06 -0.007905 -0.003574     -0.008481 -0.013098 -0.004957 -0.011460
# 2015-03-09  0.000582  0.004225      0.005843 -0.001652 -0.005447  0.001303
#
#             SP Daily Returns  SP Close
# Date
# 2015-03-03          0.004408   2107.78
# 2015-03-04         -0.001195   2098.53
# 2015-03-05          0.014378   2101.04
# 2015-03-06         -0.003929   2071.26
# 2015-03-09          0.017254   2079.43

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_WASP_df.drop(columns=['SP Close'], inplace=True)
combined_WASP_df.head()
# Out:
#                Soros   Paulson  Tiger Global       BRK    Algo 1    Algo 2  \
# Date
# 2015-03-03 -0.001266 -0.004981     -0.000496 -0.006569 -0.001942 -0.000949
# 2015-03-04  0.002230  0.003241     -0.002534  0.004213 -0.008589  0.002416
# 2015-03-05  0.004016  0.004076      0.002355  0.006726 -0.000955  0.004323
# 2015-03-06 -0.007905 -0.003574     -0.008481 -0.013098 -0.004957 -0.011460
# 2015-03-09  0.000582  0.004225      0.005843 -0.001652 -0.005447  0.001303
#
#             SP Daily Returns
# Date
# 2015-03-03          0.004408
# 2015-03-04         -0.001195
# 2015-03-05          0.014378
# 2015-03-06         -0.003929
# 2015-03-09          0.017254

# %%
combined_WASP_df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + combined_WASP_df).cumprod() - 1
cumulative_returns.head()

# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_WASP_df.boxplot(column='Soros',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
combined_WASP_df.boxplot(column='Paulson',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
combined_WASP_df.boxplot(column='Tiger Global',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
combined_WASP_df.boxplot(column='BRK',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
combined_WASP_df.boxplot(column='Algo 1',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
combined_WASP_df.boxplot(column='Algo 2',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %%
combined_WASP_df.boxplot(column='SP Daily Returns',figsize=(8,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = combined_WASP_df.std()
daily_std
# Out:
# Soros               0.007896
# Paulson             0.007026
# Tiger Global        0.010897
# BRK                 0.012919
# Algo 1              0.007623
# Algo 2              0.008341
# SP Daily Returns    0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate the daily standard deviation of S&P 500
daily_std
# Determine which portfolios are riskier than the S&P 500
daily_std = daily_std.sort_values(ascending=False)
daily_std
# Out:
# BRK                 0.012919
# Tiger Global        0.010897
# SP Daily Returns    0.008587
# Algo 2              0.008341
# Soros               0.007896
# Algo 1              0.007623
# Paulson             0.007026
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std
# Out:
# BRK                 0.205079
# Tiger Global        0.172989
# SP Daily Returns    0.136313
# Algo 2              0.132413
# Soros               0.125348
# Algo 1              0.121006
# Paulson             0.111527
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_WASP_df.rolling(window=21).std()
# Plot the rolling standard deviation
combined_WASP_df.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
daily_return_correlation = combined_WASP_df.corr()
# Display the correlation matrix
print(daily_return_correlation)
# Out:
#                      Soros   Paulson  Tiger Global       BRK    Algo 1  \
# Soros             1.000000  0.699823      0.561040  0.754157  0.320901
# Paulson           0.699823  1.000000      0.434308  0.545451  0.268631
# Tiger Global      0.561040  0.434308      1.000000  0.424125  0.164114
# BRK               0.754157  0.545451      0.424125  1.000000  0.291678
# Algo 1            0.320901  0.268631      0.164114  0.291678  1.000000
# Algo 2            0.826730  0.678085      0.507160  0.687756  0.287852
# SP Daily Returns  0.000574  0.013549     -0.001505 -0.013856 -0.033963
#
#                     Algo 2  SP Daily Returns
# Soros             0.826730          0.000574
# Paulson           0.678085          0.013549
# Tiger Global      0.507160         -0.001505
# BRK               0.687756         -0.013856
# Algo 1            0.287852         -0.033963
# Algo 2            1.000000         -0.002192
# SP Daily Returns -0.002192          1.000000

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
soros_rolling_cov = combined_WASP_df['Soros'].rolling(window=60).cov(combined_WASP_df['SP Daily Returns'])
soros_rolling_cov
# Calculate variance of S&P 500
SP5_rolling_variance = combined_WASP_df['SP Daily Returns'].rolling(window=30).var()
# Computing beta
rolling_beta = soros_rolling_cov / SP5_rolling_variance
# Plot beta trend
rolling_beta.plot(figsize=(20,10), title='Rolling 60-Day Variance of S&P 500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Variance of S&P 500 Returns'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
combined_WASP_df.ewm(halflife=21).mean()
# Out:
#                Soros   Paulson  Tiger Global       BRK    Algo 1    Algo 2  \
# Date
# 2015-03-03 -0.001266 -0.004981     -0.000496 -0.006569 -0.001942 -0.000949
# 2015-03-04  0.000511 -0.000802     -0.001532 -0.001089 -0.005320  0.000761
# 2015-03-05  0.001718  0.000878     -0.000193  0.001603 -0.003817  0.001988
# 2015-03-06 -0.000808 -0.000291     -0.002369 -0.002256 -0.004116 -0.001542
# 2015-03-09 -0.000511  0.000673     -0.000616 -0.002128 -0.004400 -0.000935
# ...              ...       ...           ...       ...       ...       ...
# 2019-04-15  0.001439  0.000450     -0.000813  0.001896  0.001175  0.001313
# 2019-04-16  0.001480  0.000448     -0.000813  0.001862  0.000912  0.001364
# 2019-04-17  0.001338  0.000223     -0.000930  0.001906  0.000548  0.001150
# 2019-04-18  0.001341  0.000256     -0.000881  0.001907  0.000511  0.001073
# 2019-04-22  0.001214  0.000009     -0.000971  0.001809  0.000516  0.000975
#
#             SP Daily Returns
# Date
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_WASP_df.mean() * 252) / (combined_WASP_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# Soros               0.342894
# Paulson            -0.491422
# Tiger Global       -0.130186
# BRK                 0.606743
# Algo 1              1.369589
# Algo 2              0.484334
# SP Daily Returns   -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo 1 outperforms the both the S&P 500 and the whales portfolios; Algo 2 outperforms the S&P 500 and Soros, Paulson and Tiger Global.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
googcsv = Path("../Starter_Code/Resources/goog_historical.csv")

# %%
googcsv
# Out:
# WindowsPath('../Starter_Code/Resources/goog_historical.csv')

# %%
goog_df = pd.read_csv(googcsv, index_col="Trade DATE", parse_dates = True, infer_datetime_format =True) 
goog_df.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
goog_df.isnull().count()
# Out:
# Symbol    250
# NOCP      250
# dtype: int64

# %%
goog_df.dropna(inplace=True)
goog_df
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40
# ...           ...      ...
# 2018-05-17   GOOG  1078.59
# 2018-05-16   GOOG  1081.77
# 2018-05-15   GOOG  1079.23
# 2018-05-14   GOOG  1100.20
# 2018-05-11   GOOG  1098.26
#
# [250 rows x 2 columns]

# %%
goog_df.dtypes
# Out:
# Symbol     object
# NOCP      float64
# dtype: object

# %%
goog_df = goog_df.drop(columns=["Symbol"])
goog_df.head()
# Out:
#                NOCP
# Trade DATE
# 2019-05-09  1162.38
# 2019-05-08  1166.27
# 2019-05-07  1174.10
# 2019-05-06  1189.39
# 2019-05-03  1185.40

# %%
goog_df = goog_df.rename(columns={"NOCP": "Google CP"})
goog_df.head()
# Out:
#             Google CP
# Trade DATE
# 2019-05-09    1162.38
# 2019-05-08    1166.27
# 2019-05-07    1174.10
# 2019-05-06    1189.39
# 2019-05-03    1185.40

# %%
# Reading data from 2nd stock
aaplcsv = Path("../Starter_Code/Resources/aapl_historical.csv")

# %%
aaplcsv
# Out:
# WindowsPath('../Starter_Code/Resources/aapl_historical.csv')

# %%
aapl_df = pd.read_csv(aaplcsv, index_col="Trade DATE", parse_dates = True, infer_datetime_format =True) 
aapl_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
aapl_df.isnull().count()
# Out:
# Symbol    250
# NOCP      250
# dtype: int64

# %%
aapl_df.dropna(inplace=True)
aapl_df
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75
# ...           ...     ...
# 2018-05-17   AAPL  186.99
# 2018-05-16   AAPL  188.18
# 2018-05-15   AAPL  186.44
# 2018-05-14   AAPL  188.15
# 2018-05-11   AAPL  188.59
#
# [250 rows x 2 columns]

# %%
aapl_df = aapl_df.drop(columns=["Symbol"])
aapl_df.head()
# Out:
#               NOCP
# Trade DATE
# 2019-05-09  200.72
# 2019-05-08  202.90
# 2019-05-07  202.86
# 2019-05-06  208.48
# 2019-05-03  211.75

# %%
aapl_df = aapl_df.rename(columns={"NOCP": "Apple CP"})
aapl_df.head()
# Out:
#             Apple CP
# Trade DATE
# 2019-05-09    200.72
# 2019-05-08    202.90
# 2019-05-07    202.86
# 2019-05-06    208.48
# 2019-05-03    211.75

# %%
# Reading data from 3rd stock
costcsv = Path("../Starter_Code/Resources/cost_historical.csv")

# %%
costcsv
# Out:
# WindowsPath('../Starter_Code/Resources/cost_historical.csv')

# %%
cost_df = pd.read_csv(costcsv, index_col="Trade DATE", parse_dates = True, infer_datetime_format =True) 
cost_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
cost_df.isnull().count()
# Out:
# Symbol    250
# NOCP      250
# dtype: int64

# %%
cost_df.dropna(inplace=True)
cost_df
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62
# ...           ...     ...
# 2018-05-17   COST  199.60
# 2018-05-16   COST  198.71
# 2018-05-15   COST  195.48
# 2018-05-14   COST  195.88
# 2018-05-11   COST  195.76
#
# [250 rows x 2 columns]

# %%
cost_df = cost_df.drop(columns=["Symbol"])
cost_df.head()
# Out:
#               NOCP
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18
# 2019-05-06  244.23
# 2019-05-03  244.62

# %%
cost_df = cost_df.rename(columns={"NOCP": "Costco CP"})
cost_df.head()
# Out:
#             Costco CP
# Trade DATE
# 2019-05-09     243.47
# 2019-05-08     241.34
# 2019-05-07     240.18
# 2019-05-06     244.23
# 2019-05-03     244.62

# %%
# Combine all stocks in a single DataFrame
combined_GAC_df = pd.concat([goog_df, aapl_df, cost_df], axis="columns", join="inner")
combined_GAC_df.index.rename('Date', inplace=True)
combined_GAC_df.sort_index(inplace=True)
combined_GAC_df.columns = ['Google CP', 'Apple CP', 'Costco CP']
combined_GAC_df.head()
# Out:
#             Google CP  Apple CP  Costco CP
# Date
# 2018-05-11    1098.26    188.59     195.76
# 2018-05-14    1100.20    188.15     195.88
# 2018-05-15    1079.23    186.44     195.48
# 2018-05-16    1081.77    188.18     198.71
# 2018-05-17    1078.59    186.99     199.60

# %%
# Reset Date index
combined_GAC_df = combined_GAC_df.sort_index(ascending=True)
combined_GAC_df
# Out:
#             Google CP  Apple CP  Costco CP
# Date
# 2018-05-11    1098.26    188.59     195.76
# 2018-05-14    1100.20    188.15     195.88
# 2018-05-15    1079.23    186.44     195.48
# 2018-05-16    1081.77    188.18     198.71
# 2018-05-17    1078.59    186.99     199.60
# ...               ...       ...        ...
# 2019-05-03    1185.40    211.75     244.62
# 2019-05-06    1189.39    208.48     244.23
# 2019-05-07    1174.10    202.86     240.18
# 2019-05-08    1166.27    202.90     241.34
# 2019-05-09    1162.38    200.72     243.47
#
# [250 rows x 3 columns]

# %%
# Reorganize portfolio data by having a column per symbol
combined_GAC_df.head()
# Out:
#             Google CP  Apple CP  Costco CP
# Date
# 2018-05-11    1098.26    188.59     195.76
# 2018-05-14    1100.20    188.15     195.88
# 2018-05-15    1079.23    186.44     195.48
# 2018-05-16    1081.77    188.18     198.71
# 2018-05-17    1078.59    186.99     199.60

# %%
# Calculate daily returns
Stock_daily_returns = combined_GAC_df.pct_change()
Stock_daily_returns.head()
# Drop NAs
Stock_daily_returns.dropna(inplace=True)
Stock_daily_returns
# Display sample data
Stock_daily_returns
# Out:
#             Google CP  Apple CP  Costco CP
# Date
# 2018-05-14   0.001766 -0.002333   0.000613
# 2018-05-15  -0.019060 -0.009088  -0.002042
# 2018-05-16   0.002354  0.009333   0.016523
# 2018-05-17  -0.002940 -0.006324   0.004479
# 2018-05-18  -0.011339 -0.003637  -0.003206
# ...               ...       ...        ...
# 2019-05-03   0.019602  0.012431   0.007953
# 2019-05-06   0.003366 -0.015443  -0.001594
# 2019-05-07  -0.012855 -0.026957  -0.016583
# 2019-05-08  -0.006669  0.000197   0.004830
# 2019-05-09  -0.003335 -0.010744   0.008826
#
# [249 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
stock_portfolio_returns = Stock_daily_returns.dot(weights)
stock_portfolio_returns = pd.DataFrame(stock_portfolio_returns)
stock_portfolio_returns.columns=["Stock Returns"]
# Display sample data
stock_portfolio_returns.head()
# Out:
#             Stock Returns
# Date
# 2018-05-14       0.000015
# 2018-05-15      -0.010064
# 2018-05-16       0.009403
# 2018-05-17      -0.001595
# 2018-05-18      -0.006061

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
final_portfolio = pd.concat([combined_WASP_df, stock_portfolio_returns], axis="columns", join="inner")
final_portfolio.head()
# Out:
#                Soros   Paulson  Tiger Global       BRK    Algo 1    Algo 2  \
# Date
# 2018-05-14  0.000000  0.000000      0.000000  0.000000  0.000915  0.001635
# 2018-05-15 -0.000726 -0.001409     -0.003189 -0.014606 -0.001135 -0.001139
# 2018-05-16  0.008637  0.006244      0.005480  0.004310 -0.002326  0.003341
# 2018-05-17 -0.001955  0.002524     -0.006267 -0.005140 -0.006949  0.005205
# 2018-05-18 -0.004357 -0.002672     -0.012832 -0.002212  0.002557 -0.002496
#
#             SP Daily Returns  Stock Returns
# Date
# 2018-05-14          0.006889       0.000015
# 2018-05-15         -0.004044      -0.010064
# 2018-05-16          0.000857       0.009403
# 2018-05-17          0.002639      -0.001595
# 2018-05-18         -0.007333      -0.006061

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
final_portfolio.isnull().count()
# Out:
# Soros               236
# Paulson             236
# Tiger Global        236
# BRK                 236
# Algo 1              236
# Algo 2              236
# SP Daily Returns    236
# Stock Returns       236
# dtype: int64

# %%
final_portfolio.dropna(inplace=True)
final_portfolio
# Out:
#                Soros   Paulson  Tiger Global       BRK    Algo 1    Algo 2  \
# Date
# 2018-05-14  0.000000  0.000000      0.000000  0.000000  0.000915  0.001635
# 2018-05-15 -0.000726 -0.001409     -0.003189 -0.014606 -0.001135 -0.001139
# 2018-05-16  0.008637  0.006244      0.005480  0.004310 -0.002326  0.003341
# 2018-05-17 -0.001955  0.002524     -0.006267 -0.005140 -0.006949  0.005205
# 2018-05-18 -0.004357 -0.002672     -0.012832 -0.002212  0.002557 -0.002496
# ...              ...       ...           ...       ...       ...       ...
# 2019-04-15 -0.001422 -0.001156      0.000398 -0.010492 -0.004331 -0.004572
# 2019-04-16  0.002699  0.000388     -0.000831  0.000837 -0.006945  0.002899
# 2019-04-17 -0.002897 -0.006467     -0.004409  0.003222 -0.010301 -0.005228
# 2019-04-18  0.001448  0.001222      0.000582  0.001916 -0.000588 -0.001229
# 2019-04-22 -0.002586 -0.007333     -0.003640 -0.001088  0.000677 -0.001936
#
#             SP Daily Returns  Stock Returns
# Date
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
final_portfolio_std = final_portfolio.std()
final_annualized_std = final_portfolio_std * np.sqrt(252)
final_annualized_std
# Out:
# Soros               0.146812
# Paulson             0.116928
# Tiger Global        0.232898
# BRK                 0.247305
# Algo 1              0.133927
# Algo 2              0.139499
# SP Daily Returns    0.152469
# Stock Returns       0.211627
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
final_portfolio.rolling(window=21).std()
# Plot rolling standard deviation
final_portfolio.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
final_portfolio_correlation = final_portfolio.corr()
final_portfolio_correlation.plot(figsize=(20,10), title='Final Portfolio Correlation')
# Out:
# <AxesSubplot:title={'center':'Final Portfolio Correlation'}>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Follow the steps below calculate and plot Beta

# (1) Calculate covariance of a single portfolio
final_portfolio_cov = final_portfolio['Stock Returns'].rolling(window=60).cov(final_portfolio['SP Daily Returns'])
final_portfolio_cov
# (2) Calculate variance of S&P 500
Port_SP5_rolling_variance = final_portfolio['SP Daily Returns'].rolling(window=60).var()
# (3) Computing beta
Port_rolling_beta = final_portfolio_cov / Port_SP5_rolling_variance
# (4) Plot beta trend
Port_rolling_beta.plot(figsize=(20,10), title='My Stock Returns Portfolio - Rolling 60-Day Variance of S&P 500 Returns')
# Out:
# <AxesSubplot:title={'center':'My Stock Returns Portfolio - Rolling 60-Day Variance of S&P 500 Returns'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
final_portfolio_sharpe_ratios = (final_portfolio.mean() * 252) / (final_portfolio.std() * np.sqrt(252))
final_portfolio_sharpe_ratios
# Out:
# Soros               0.380007
# Paulson             0.227577
# Tiger Global       -1.066635
# BRK                 0.103006
# Algo 1              2.001260
# Algo 2              0.007334
# SP Daily Returns   -0.427676
# Stock Returns       0.876152
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
final_portfolio_sharpe_ratios.plot(kind="bar", title="My Final Portfolio Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'My Final Portfolio Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
## My stock returns portfolio outperforms all the whale investments and the S&P 500 with the excpetion of Algorithm 1.

# %%
## Harry Torres - 01/18/2021
